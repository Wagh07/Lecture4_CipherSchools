# %%
# Naming Convention

abc123 =20
print(abc123)
# Out:
# 20

# %%
# Everything in python is treated as object

a=10
print(type(a))
# Out:
# <class 'int'>

# %%
#Memory Adresses of variables(samevariables has same memory address)

a=10
b=10
c=20
print(id(a))
print(id(b))
print(id(c))
# Out:
# 140262077301264
# 140262077301264
# 140262077301584
